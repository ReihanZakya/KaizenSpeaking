# %%
# !ollama list
# Out:
# NAME                         ID              SIZE      MODIFIED
# KimiDandy/kaizenv9:latest    fdd3c984e575    4.7 GB    43 seconds ago
# KimiDandy/kaizenv8:latest    f8211a84d197    4.7 GB    3 hours ago
# llama3.1:latest              42182419e950    4.7 GB    3 hours ago
# KimiDandy/kaizenv7:latest    f457754ae83b    16 GB     15 hours ago
# KimiDandy/kaizenv6:latest    f35655ea861d    16 GB     20 hours ago
# KimiDandy/kaizenv5:latest    005caff573d1    16 GB     21 hours ago

# %%
# !ollama create KimiDandy/kaizenv9 -f Modelfile
# Out:
# transferring model data ⠋ transferring model data ⠹ transferring model data ⠸ transferring model data 0% ⠸ transferring model data 32% ⠴ transferring model data 50% ⠴ transferring model data 85% ⠧ transferring model data 100%
# converting model ⠋ transferring model data 100%
# converting model ⠙ transferring model data 100%
# converting model ⠹ transferring model data 100%
# converting model ⠸ transferring model data 100%
# converting model ⠼ transferring model data 100%
# converting model ⠴ transferring model data 100%
# converting model ⠦ transferring model data 100%
# converting model ⠧ transferring model data 100%
# converting model ⠇ transferring model data 100%
# converting model ⠏ transferring model data 100%
# converting model ⠋ transferring model data 100%
# converting model ⠙ transferring model data 100%
# converting model ⠹ transferring model data 100%
# converting model ⠸ transferring model data 100%
# converting model ⠼ transferring model data 100%
# ...

# %%
# !python key.py
# Out:
# /root/.ollama/id_ed25519.pub
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIHPsmCQ9MbDPQrBRquEzgTL2f8fj/6qLVMNgj67apJD3

# %%
# !ollama push KimiDandy/kaizenv9
# Out:
# retrieving manifest ⠋ retrieving manifest ⠙ retrieving manifest ⠹ retrieving manifest ⠸ retrieving manifest ⠼ retrieving manifest ⠴ retrieving manifest ⠦ retrieving manifest ⠧ retrieving manifest ⠇ retrieving manifest ⠏ retrieving manifest ⠋ retrieving manifest ⠙ retrieving manifest ⠹ retrieving manifest ⠸ retrieving manifest
# pushing 8eeb52dfb3bb... 100% ▕████████████████▏ 4.7 GB                         retrieving manifest
# pushing 8eeb52dfb3bb... 100% ▕████████████████▏ 4.7 GB                         retrieving manifest
# pushing 8eeb52dfb3bb... 100% ▕████████████████▏ 4.7 GB                         retrieving manifest
# pushing 8eeb52dfb3bb... 100% ▕████████████████▏ 4.7 GB                         retrieving manifest
# pushing 8eeb52dfb3bb... 100% ▕████████████████▏ 4.7 GB                         retrieving manifest
# pushing 8eeb52dfb3bb... 100% ▕████████████████▏ 4.7 GB                         retrieving manifest
# ...
